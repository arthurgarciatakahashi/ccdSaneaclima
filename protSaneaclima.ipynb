# %%
#!pip install -U langchain-openai langchain
# !pip install -U langchain-openai langchain langchain-community langchainhub

# %%
import os

# Define a chave diretamente como variável de ambiente
os.environ["OPENAI_API_KEY"] = "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"

print("Chave de API configurada com sucesso!")

# %%
from langchain_core.tools import Tool

# --- DEFINIÇÃO DAS FUNÇÕES TÉCNICAS ---

def consultar_telemetria(sensor_id):
    """
    Simula o acesso a um pipeline de dados IoT de vazão e pressão.
    Na prática, aqui rodaria um modelo como o BASWE para detectar anomalias.
    """
    return "Status do Sensor: Pressão em 52 mca (Limite: 40 mca). Alerta de Anomalia Crítica detectado pelo modelo estatístico."

def verificar_clima(regiao):
    """Consulta condições meteorológicas que afetam a infraestrutura."""
    return "Relatório Climático: Tempestade severa em andamento com alta incidência de raios e risco de transbordamento local."

def base_conhecimento_manutencao(setor):
    """Acessa o histórico de ordens de serviço e manutenções programadas."""
    return "Registro de Manutenção: Não existem obras ou intervenções técnicas programadas para as últimas 48 horas neste setor."

# --- CRIAÇÃO DA LISTA DE FERRAMENTAS ---

tools = [
    Tool(
        name="Telemetria_Saneamento",
        func=consultar_telemetria,
        description="Útil para verificar dados em tempo real de pressão e vazão nos sensores da rede."
    ),
    Tool(
        name="Consulta_Climatica",
        func=verificar_clima,
        description="Útil para entender se eventos climáticos externos explicam variações nos dados dos sensores."
    ),
    Tool(
        name="Sistema_Manutencao",
        func=base_conhecimento_manutencao,
        description="Útil para confirmar se uma anomalia nos dados é fruto de uma obra técnica planejada."
    )
]

print("Ferramentas configuradas com sucesso!")

# %%
from langchain_openai import ChatOpenAI
from langchain.agents import AgentExecutor, create_openai_tools_agent
from langchain import hub

# 1. Definimos o modelo (LLM)
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# 2. Puxamos o prompt específico para Tools (diferente do ReAct)
prompt = hub.pull("hwchase17/openai-tools-agent")

# 3. Criamos o Agente usando a técnica que você achou
# 'tools' deve ser a lista definida no Passo 3
agent = create_openai_tools_agent(llm, tools, prompt)

# 4. Criamos o Executor
agent_executor = AgentExecutor(
    agent=agent,
    tools=tools,
    verbose=True
)

print("✅ AGORA SIM! Agente de Tools configurado com sucesso.")

# %%
# !pip install langchain-community langchainhub
